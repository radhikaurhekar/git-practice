# %%
products = ["t-shirt", "mug", "hat", "book", "keychain"]

# %%
inventory={}

# %%
print("Enter inventory quantity for each product:")
for product in products:
    quantity = int(input(product + ": "))
    inventory[product] = quantity
# Out:
# Enter inventory quantity for each product:
# t-shirt:  3
# mug:  4
# hat:  5
# book:  6
# keychain:  7

# %%
product=input("Name of product:")
# Out:
# Name of product: mug

# %%
customer_orders=set()

# %%
continue_ordering=input("Do you want to order product?: yes/no").
# Out:
# Do you want to order product?: yes/no yes

# %%
while continue_ordering == "yes":
    prod_name = input("Enter product to order: ")
# Out:
# Enter product to order:  hat
# Enter product to order:  book
# Enter product to order:  keychain
# Enter product to order:  no

# %%
inventory = {
    "t-shirt": 10,
    "mug": 5,
    "hat": 7,
    "book": 8,
    "keychain": 12
}
